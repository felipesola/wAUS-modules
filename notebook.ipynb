# %%
from steps.ingestion import call_df
from steps.variables_split import train_test
from steps.pipe_step import pipe
from steps.model import model_run

# %%
'''This notebook will 'orchestrate' the functions contained in the 'steps' folder'''

#First step: dataset import

df_obj = call_df()

# %%
#Second step: split dataset into train and test data

X_train, X_test, y_train, y_test = train_test(df_obj)

# %%
#Third step: pipeline

pipe_obj = pipe()

# %%
#Fourth step: model run

model_run(pipe_obj, X_train, X_test, y_train, y_test)
